# %% [markdown]
# # ДЗ №1 СУНЦ МГУ - Numpy practice

# %% [markdown]
# _Задачи позаимствованы из курса ML ФКН ПМИ где они были позаимствованы из курса практикума кафедры ММП факультета ВМК МГУ_

# %% [markdown]
# ### Туториальные задачи
# __(9 баллов)__
#
# Ниже приведены задачи на работу с numpy-массивами. Для каждой из задач нужно привести 2 реализации: одна без использования numpy (cчитайте, что там, где на входе или выходе должны быть numpy array, будут просто списки), а вторая полностью векторизованная (без использования питоновских циклов/map/list comprehension). Невекторизованная реализация каждой из задач оценивается в __0.5 балла__, векторизованная – в __1 балл__.
#
# Реализации без использования векторизации нужно записать в файл functions.py, а векторизованные &mdash; в файл functions_vectorized.py
#
# Для каждой задачи, приведённой ниже сравните скорость работы невекторизованной и векторизованной реализации. С помощью пакета matplotlib постройте графики времени работы в зависимости от размера данных. __Графики должны выглядеть опрятно!__ То есть должны быть подписаны оси, названия графиков, и т.д. Например, ниже представлены хороший и плохой графики:

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

data_size = np.array([10, 30, 70, 120])
time_non_vectorized = data_size ** 2 + 10
time_vectorized = data_size ** 1.5

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 5))

ax1.plot(data_size, time_non_vectorized)
ax1.plot(data_size, time_vectorized)
ax1.set_title(u"Плохой график")
ax1.set_xlabel(u"Размер данных")
ax1.set_ylabel(u"Время")

ax2.plot(data_size, time_non_vectorized, label=u"Невекторизованная")
ax2.plot(data_size, time_vectorized, label=u"Векторизованная")
ax2.set_title(u"Хороший график")
ax2.set_xlabel(u"Длина массива")
ax2.set_ylabel(u"Время (с)")
ax2.grid()
ax2.legend()

f.show()
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/figure.py:402: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# * __Задача 1__: Подсчитать произведение ненулевых элементов на диагонали прямоугольной матрицы.
#  Например, для X = np.array([[1, 0, 1], [2, 0, 2], [3, 0, 3], [4, 4, 4]]) ответ – 3.

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
from time import time
import functions as f
import functions_vectorized as fv
from importlib import reload


reload(f)
reload(fv)


# %matplotlib inline


time_vec = []
time_unvec = []


for diag in range(1, 400):
    sum_time_vec = 0
    sum_time_unvec = 0
    for _x_ in range(400):
        ln_x = random.randint(diag, 400)
        X = np.random.rand(ln_x, diag) * 10
        tmp = time()
        f.prod_non_zero_diag(X)
        sum_time_unvec += time() - tmp
        tmp = time()
        fv.prod_non_zero_diag(X)
        sum_time_vec += time() - tmp
    for _y_ in range(400):
        ln_y = random.randint(diag, 400)
        X = np.random.rand(diag, ln_y) * 10
        tmp = time()
        f.prod_non_zero_diag(X)
        sum_time_unvec += time() - tmp
        tmp = time()
        fv.prod_non_zero_diag(X)
        sum_time_vec += time() - tmp
    time_vec.append(sum_time_vec / 800 * 1000)
    time_unvec.append(sum_time_unvec / 800 * 1000)

    
plt.plot([i for i in range(1, 400)], time_vec, label="Векторизованная")
plt.plot([i for i in range(1, 400)], time_unvec, label="Невекторизованная")
plt.xlabel("Длина диагонали")
plt.ylabel("Время, мc")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
#
#
# * __Задача 2__: Даны два вектора x и y. Проверить, задают ли они одно и то же мультимножество.
#   Например, для x = np.array([1, 2, 2, 4]), y = np.array([4, 2, 1, 2]) ответ – True.

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
from time import time
import functions as f
import functions_vectorized as fv
from importlib import reload
from collections import Counter


reload(f)
reload(fv)


# %matplotlib inline


time_vec = []
time_unvec = []


for n in range(2, 1000):
    sum_time_vec = 0
    sum_time_unvec = 0
    for i in range(5000):
        k1 = random.randint(1, 10)
        X = np.random.rand(n) * k1
        k2 = random.randint(1, 10)
        Y = np.random.rand(n) * k2
        tmp = time()
        f.are_multisets_equal(X, Y)
        sum_time_unvec += time() - tmp
        tmp = time()
        fv.are_multisets_equal(X, Y)
        sum_time_vec += time() - tmp
    time_vec.append(sum_time_vec / 5000 * 1000)
    time_unvec.append(sum_time_unvec / 5000 * 1000)
    

plt.plot([i for i in range(2, 1000)], time_vec, label="Векторизованная")
plt.plot([i for i in range(2, 1000)], time_unvec, label="Невекторизованная")
plt.xlabel("Длина массива")
plt.ylabel("Время, мc")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# * __Задача 3__: Найти максимальныйэлемент в векторе x среди элементов, перед которыми стоит нулевой.
#  Например, для x = np.array([6, 2, 0, 3, 0, 0, 5, 7, 0]) ответ – 5.

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
from time import time
import functions as f
import functions_vectorized as fv
from importlib import reload


reload(f)
reload(fv)


# %matplotlib inline


time_vec = []
time_unvec = []


for n in range(2, 1000):
    sum_time_vec = 0
    sum_time_unvec = 0
    for i in range(5000):
        X = np.random.randint(1, 100, size=n)
        k = random.randint(1, n // 2)
        indexes = np.random.randint(n - 1, size=k)
        X[indexes] = 0
        tmp = time()
        f.max_after_zero(X)
        sum_time_unvec += time() - tmp
        tmp = time()
        fv.max_after_zero(X)
        sum_time_vec += time() - tmp
    time_vec.append(sum_time_vec / 5000 * 1000)
    time_unvec.append(sum_time_unvec / 5000 * 1000)

    
plt.plot([i for i in range(2, 1000)], time_vec, label="Векторизованная")
plt.plot([i for i in range(2, 1000)], time_unvec, label="Невекторизованная")
plt.xlabel("Длина массива")
plt.ylabel("Время, мc")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
#
#
# * __ Задача 4__: Дан трёхмерный массив, содержащий изображение, размера (height, width, numChannels), а также вектор длины numChannels. Сложить каналы изображения с указанными весами, и вернуть результат в виде матрицы размера (height, width). В ноутбуке приведите пример работы функции – преобразуйте цветное изображение в оттенки серого, использовав коэффициенты np.array([0.299, 0.587, 0.114]). Считать реальное изображение можно при помощи функции scipy.misc.imread (если изображение не в формате png, установите пакет pillow).

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
from time import time
import functions as f
import functions_vectorized as fv
from PIL import Image, ImageDraw
from importlib import reload


reload(f)
reload(fv)


img = np.array(Image.open("prosto_bibizyana.png"))
coef = np.array([0.299, 0.587, 0.114])
tmp = time()
result = f.convert_image(img, coef)
print("Время работы невекторизованной функции:", time() - tmp)
tmp = time()
result = fv.convert_image(img, coef)
print("Время работы векторизованной функции:", time() - tmp)
new_img = Image.fromarray(result)
display(new_img)
# Out:
# Время работы невекторизованной функции: 0.1836857795715332
# Время работы векторизованной функции: 0.0033941268920898438
# <PIL.Image.Image image mode=L size=626x352>

# %% [markdown]
# * __Задача 5__: Реализовать кодирование длин серий (Run-length encoding). Для некоторого вектора x необходимо вернуть кортеж из двух векторов одинаковой длины. Первый содержит числа, а второй - сколько раз их нужно повторить.
#  Например, для x = np.array([2, 2, 2, 3, 3, 3, 5]) ответ – (np.array([2, 3, 5]), np.array([3, 3, 1])).

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
from time import time
import functions as f
import functions_vectorized as fv
from importlib import reload
from collections import Counter


reload(f)
reload(fv)


# %matplotlib inline


time_vec = []
time_unvec = []


for n in range(10, 1000):
    sum_time_vec = 0
    sum_time_unvec = 0
    for i in range(5000):
        X = np.random.randint(n // 5, size=n)
        tmp = time()
        f.run_length_encoding(X)
        sum_time_unvec += time() - tmp
        tmp = time()
        fv.run_length_encoding(X)
        sum_time_vec += time() - tmp
    time_vec.append(sum_time_vec / 5000 * 1000)
    time_unvec.append(sum_time_unvec / 5000 * 1000)

    
plt.plot([i for i in range(10, 1000)], time_vec, label="Векторизованная")
plt.plot([i for i in range(10, 1000)], time_unvec, label="Невекторизованная")
plt.xlabel("Длина массива")
plt.ylabel("Время, мc")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
#
#
# * __Задача 6__: Даны две выборки объектов - X и Y. Вычислить матрицу евклидовых расстояний между объектами. Дополнительно сравните с функцией scipy.spatial.distance.cdist по скорости работы (сравнения приведите ниже в ноутбуке).

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
from time import time
import functions as f
import functions_vectorized as fv
from importlib import reload
from collections import Counter


reload(f)
reload(fv)


# %matplotlib inline


time_vec = []
time_unvec = []


for n in range(1, 200):
    sum_time_vec = 0
    sum_time_unvec = 0
    for i in range(100):
        X = np.random.rand(n, 2)
        Y = np.random.rand(n, 2)
        tmp = time()
        fv.pairwise_distance(X, Y)
        sum_time_vec += time() - tmp
        tmp = time()
        f.pairwise_distance(X, Y)
        sum_time_unvec += time() - tmp
    time_vec.append(sum_time_vec / 100 * 1000)
    time_unvec.append(sum_time_unvec / 100 * 1000)

    
plt.plot([i for i in range(1, 200)], time_vec, label="Векторизованная")
plt.plot([i for i in range(1, 200)], time_unvec, label="Невекторизованная")
plt.xlabel("Длина массива")
plt.ylabel("Время, мс")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Туториал по Markdown
#
# __(1 балл)__
#
# Напишите краткий (а в данной домашке ещё и почти бесмысленный) отчёт с использованием 4-5 различных вариантов разметки/выделения текста.

# %% [markdown]
# ## Отчёт по домашке
# Мне удалось посторить несколько ***графиков***, которые показывают зависимость *времени* от *размера массива*.
# Также я изменил цветовую гамму __изображения обезьяны__
